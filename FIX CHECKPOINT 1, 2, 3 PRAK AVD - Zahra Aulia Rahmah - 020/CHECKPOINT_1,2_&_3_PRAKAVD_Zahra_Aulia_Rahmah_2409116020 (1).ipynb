# %% [markdown]
# # **MINI PROJECT 1**
# Zahra Aulia Rahmah - 2409226020 - Praktikum AVD Semester 2

# %% [markdown]
# # BUSINNESS UNDERSTANDING

# %% [markdown]
# # Business Objective

# %% [markdown]
# Netflix adalah salah satu layanan streaming terbesar di dunia yang memproduksi berbagai film orisinal. Rating IMDb menjadi indikator utama dalam mengukur kualitas dan popularitas film di platform ini.
#
# Tujuan utama proyek ini adalah untuk menganalisis faktor-faktor yang mempengaruhi rating IMDb film Netflix berdasarkan genre, durasi, dan tahun rilis. Dengan wawasan ini, Netflix dapat meningkatkan kualitas film yang diproduksi, menyesuaikan strategi pemasaran, serta mengoptimalkan rekomendasi film untuk pengguna.

# %% [markdown]
# # Assess Situation

# %% [markdown]
# Dalam industri streaming yang kompetitif, Netflix bersaing dengan platform lain seperti Disney+, HBO Max, dan Amazon Prime. Pemahaman mendalam terhadap tren rating film dapat membantu Netflix dalam mengembangkan strategi produksi dan distribusi yang lebih efektif.
#
# Faktor-faktor yang dapat mempengaruhi rating IMDb meliputi:
# - **Genre:** Apakah ada genre tertentu yang cenderung memiliki rating lebih tinggi atau lebih rendah?
# - **Durasi:** Apakah durasi film berhubungan dengan rating yang diperoleh?
# - **Tahun Rilis:** Apakah ada tren peningkatan atau penurunan rating dari tahun ke tahun?
#
# Dengan menganalisis faktor-faktor ini, Netflix dapat mengambil keputusan yang lebih baik dalam pengembangan film masa depan.

# %% [markdown]
# # Data Mining Goals

# %% [markdown]
# - Menganalisis distribusi rating IMDb berdasarkan genre film.
# - Mengukur hubungan antara durasi film dan rating IMDb.
# - Melihat tren rata-rata rating IMDb dari tahun ke tahun.
# - Menggunakan model regresi sederhana untuk memprediksi rating berdasarkan genre dan durasi film.

# %% [markdown]
# # Project Plan

# %% [markdown]
# 1. **Pengumpulan Data**:
#
# Menggunakan dataset "Netflix Original Films IMDB Scores" dari Kaggle.
# 2. **Eksplorasi Data**:
#
# Memeriksa distribusi rating, genre, dan durasi.
# 3. **Analisis Korelasi**:
#
#  Mengidentifikasi hubungan antara durasi dan rating.
# 4. **Visualisasi Data**:
#
#  Menampilkan tren rating berdasarkan genre dan tahun rilis.
# 5. **Model Prediksi**:
#
# Membangun model sederhana untuk memprediksi rating berdasarkan fitur yang tersedia.
# 6. **Interpretasi & Kesimpulan**:
#
# Menyusun laporan hasil analisis dan wawasan yang didapat.

# %% [markdown]
# # **CHECKPOINT 2**

# %% [markdown]
# # **Data Understanding**

# %% [markdown]
# ## 1. Sumber Data
# > https://www.kaggle.com/datasets/luiscorter/netflix-original-films-imdb-scores

# %% [markdown]
# ## 2. Pemeriksaan Terhadap Struktur Data

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ### Membaca Data

# %%
df = pd.read_csv("/content/.config/NetflixOriginals.csv", encoding="ISO-8859-1")

df
# Out:
#                                            Title                  Genre  \
# 0                                Enter the Anime            Documentary
# 1                                    Dark Forces               Thriller
# 2                                        The App  Science fiction/Drama
# 3                                 The Open House        Horror thriller
# 4                                    Kaali Khuhi                Mystery
# ..                                           ...                    ...
# 579        Taylor Swift: Reputation Stadium Tour           Concert Film
# 580  Winter on Fire: Ukraine's Fight for Freedom            Documentary
# 581                      Springsteen on Broadway           One-man show
# 582    Emicida: AmarElo - It's All For Yesterday            Documentary
# 583     David Attenborough: A Life on Our Planet            Documentary
#
#               Premiere  Runtime  IMDB Score                  Language
# ...

# %% [markdown]
# ### Pengecekan Struktur Data

# %%
print("Jika ingin menampilkan Beberapa Row Data:")
df.head(3)

print("\nJika ingin menampilkan Keseluruhan Data:")
df

print("\nMenampilkan 5 baris pertama dengan df.head():")
df.head()

print("\nMenampilkan 5 baris terakhir dengan df.tail():")
df.tail()
# Out:
# Jika ingin menampilkan Beberapa Row Data:
#
# Jika ingin menampilkan Keseluruhan Data:
#
# Menampilkan 5 baris pertama dengan df.head():
#
# Menampilkan 5 baris terakhir dengan df.tail():
#                                            Title         Genre  \
# 579        Taylor Swift: Reputation Stadium Tour  Concert Film
# 580  Winter on Fire: Ukraine's Fight for Freedom   Documentary
# 581                      Springsteen on Broadway  One-man show
# 582    Emicida: AmarElo - It's All For Yesterday   Documentary
# 583     David Attenborough: A Life on Our Planet   Documentary
#
#               Premiere  Runtime  IMDB Score                  Language
# 579  December 31, 2018      125         8.4                   English
# 580    October 9, 2015       91         8.4  English/Ukranian/Russian
# 581  December 16, 2018      153         8.5                   English
# 582   December 8, 2020       89         8.6                Portuguese
# ...

# %%
print("\nMenampilkan ringkasan informasi dataset dengan df.info():")
df.info()

print("\nMenampilkan jumlah baris dan kolom dengan df.shape:")
df.shape

print("\nMenampilkan tipe data setiap kolom dengan df.dtypes:")
df.dtypes
# Out:
# Menampilkan ringkasan informasi dataset dengan df.info():
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 584 entries, 0 to 583
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Title       584 non-null    object
#  1   Genre       584 non-null    object
#  2   Premiere    584 non-null    object
#  3   Runtime     584 non-null    int64
#  4   IMDB Score  584 non-null    float64
#  5   Language    584 non-null    object
# dtypes: float64(1), int64(1), object(4)
# memory usage: 27.5+ KB
#
# Menampilkan jumlah baris dan kolom dengan df.shape:
#
# Menampilkan tipe data setiap kolom dengan df.dtypes:
# Title          object
# Genre          object
# Premiere       object
# Runtime         int64
# IMDB Score    float64
# Language       object
# dtype: object

# %%
print("\nMenampilkan statistik deskriptif dengan df.describe():")
df.describe()
# Out:
# Menampilkan statistik deskriptif dengan df.describe():
#           Runtime  IMDB Score
# count  584.000000  584.000000
# mean    93.577055    6.271747
# std     27.761683    0.979256
# min      4.000000    2.500000
# 25%     86.000000    5.700000
# 50%     97.000000    6.350000
# 75%    108.000000    7.000000
# max    209.000000    9.000000

# %%
print("\nMenghitung korelasi antar kolom numerik dengan df.corr():")
print(df.corr(numeric_only=True))
# Out:
# Menghitung korelasi antar kolom numerik dengan df.corr():
#              Runtime  IMDB Score
# Runtime     1.000000   -0.040896
# IMDB Score -0.040896    1.000000

# %% [markdown]
# # **Data Preparation**

# %% [markdown]
# ## 1. Sumber Data
# > https://www.kaggle.com/datasets/luiscorter/netflix-original-films-imdb-scores

# %% [markdown]
# ## 2. Pengecekan Terhadap Data

# %%
import pandas as pd

# %%
df = pd.read_csv("/content/.config/NetflixOriginals.csv", encoding="ISO-8859-1")

df
# Out:
#                                            Title                  Genre  \
# 0                                Enter the Anime            Documentary
# 1                                    Dark Forces               Thriller
# 2                                        The App  Science fiction/Drama
# 3                                 The Open House        Horror thriller
# 4                                    Kaali Khuhi                Mystery
# ..                                           ...                    ...
# 579        Taylor Swift: Reputation Stadium Tour           Concert Film
# 580  Winter on Fire: Ukraine's Fight for Freedom            Documentary
# 581                      Springsteen on Broadway           One-man show
# 582    Emicida: AmarElo - It's All For Yesterday            Documentary
# 583     David Attenborough: A Life on Our Planet            Documentary
#
#               Premiere  Runtime  IMDB Score                  Language
# ...

# %% [markdown]
# ### Missing Value

# %%
print((df.isna().sum() / len(df)) * 100)
# Out:
# Title         0.0
# Genre         0.0
# Premiere      0.0
# Runtime       0.0
# IMDB Score    0.0
# Language      0.0
# dtype: float64

# %% [markdown]
# Melakukan pengecekan nilai kosong pada kolom Runtime

# %%
df[df['Runtime'].isnull()]
# Out:
# Empty DataFrame
# Columns: [Title, Genre, Premiere, Runtime, IMDB Score, Language]
# Index: []

# %% [markdown]
# Melakukan pengecekan nilai kosong pada estimasi kerugian

# %%
df[df['Language'].isnull()]
# Out:
# Empty DataFrame
# Columns: [Title, Genre, Premiere, Runtime, IMDB Score, Language]
# Index: []

# %% [markdown]
# Melakukan Imputasi

# %%
df['Genre'].dropna().describe()
# Out:
# count             584
# unique            115
# top       Documentary
# freq              159
# Name: Genre, dtype: object

# %% [markdown]
# Menghapus Missing Value

# %%
df = df.drop('Genre', axis=1)

# %%
df
# Out:
#                                            Title           Premiere  Runtime  \
# 0                                Enter the Anime     August 5, 2019       58
# 1                                    Dark Forces    August 21, 2020       81
# 2                                        The App  December 26, 2019       79
# 3                                 The Open House   January 19, 2018       94
# 4                                    Kaali Khuhi   October 30, 2020       90
# ..                                           ...                ...      ...
# 579        Taylor Swift: Reputation Stadium Tour  December 31, 2018      125
# 580  Winter on Fire: Ukraine's Fight for Freedom    October 9, 2015       91
# 581                      Springsteen on Broadway  December 16, 2018      153
# 582    Emicida: AmarElo - It's All For Yesterday   December 8, 2020       89
# 583     David Attenborough: A Life on Our Planet    October 4, 2020       83
#
#      IMDB Score                  Language
# ...

# %%
pd.DataFrame(df.isna().sum() / len(df) * 100, columns=['Null Ratio %'])
# Out:
#             Null Ratio %
# Title                0.0
# Premiere             0.0
# Runtime              0.0
# IMDB Score           0.0
# Language             0.0

# %% [markdown]
# Duplikat Value

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Title, Premiere, Runtime, IMDB Score, Language]
# Index: []

# %%
df = df.drop_duplicates()

# %%
df
# Out:
#                                            Title           Premiere  Runtime  \
# 0                                Enter the Anime     August 5, 2019       58
# 1                                    Dark Forces    August 21, 2020       81
# 2                                        The App  December 26, 2019       79
# 3                                 The Open House   January 19, 2018       94
# 4                                    Kaali Khuhi   October 30, 2020       90
# ..                                           ...                ...      ...
# 579        Taylor Swift: Reputation Stadium Tour  December 31, 2018      125
# 580  Winter on Fire: Ukraine's Fight for Freedom    October 9, 2015       91
# 581                      Springsteen on Broadway  December 16, 2018      153
# 582    Emicida: AmarElo - It's All For Yesterday   December 8, 2020       89
# 583     David Attenborough: A Life on Our Planet    October 4, 2020       83
#
#      IMDB Score                  Language
# ...

# %% [markdown]
# Outliers

# %%
results = []

cols = df.select_dtypes(include=['float64', 'int64'])

for col in cols:
  q1 = df[col].quantile(0.25)
  q3 = df[col].quantile(0.75)
  iqr = q3 - q1
  lower_bound = q1 - 1.5*iqr
  upper_bound = q3 + 1.5*iqr
  outliers = df[(df[col] < lower_bound) | (df[col] > upper_bound)]
  percent_outliers = (len(outliers)/len(df))*100
  results.append({'Kolom': col, 'Persentase Outliers': percent_outliers})

# Dataframe dari list hasil
results_df = pd.DataFrame(results)
results_df.set_index('Kolom', inplace=True)
results_df = results_df.rename_axis(None, axis=0).rename_axis('Kolom', axis=1)

# Tampilkan dataframe
display(results_df)
# Out:
# Kolom       Persentase Outliers
# Runtime               12.842466
# IMDB Score             1.541096

# %%
df
# Out:
#                                            Title           Premiere  Runtime  \
# 0                                Enter the Anime     August 5, 2019       58
# 1                                    Dark Forces    August 21, 2020       81
# 2                                        The App  December 26, 2019       79
# 3                                 The Open House   January 19, 2018       94
# 4                                    Kaali Khuhi   October 30, 2020       90
# ..                                           ...                ...      ...
# 579        Taylor Swift: Reputation Stadium Tour  December 31, 2018      125
# 580  Winter on Fire: Ukraine's Fight for Freedom    October 9, 2015       91
# 581                      Springsteen on Broadway  December 16, 2018      153
# 582    Emicida: AmarElo - It's All For Yesterday   December 8, 2020       89
# 583     David Attenborough: A Life on Our Planet    October 4, 2020       83
#
#      IMDB Score                  Language
# ...

# %% [markdown]
# Incosistent Value

# %%
df
# Out:
#                                            Title           Premiere  Runtime  \
# 0                                Enter the Anime     August 5, 2019       58
# 1                                    Dark Forces    August 21, 2020       81
# 2                                        The App  December 26, 2019       79
# 3                                 The Open House   January 19, 2018       94
# 4                                    Kaali Khuhi   October 30, 2020       90
# ..                                           ...                ...      ...
# 579        Taylor Swift: Reputation Stadium Tour  December 31, 2018      125
# 580  Winter on Fire: Ukraine's Fight for Freedom    October 9, 2015       91
# 581                      Springsteen on Broadway  December 16, 2018      153
# 582    Emicida: AmarElo - It's All For Yesterday   December 8, 2020       89
# 583     David Attenborough: A Life on Our Planet    October 4, 2020       83
#
#      IMDB Score                  Language
# ...

# %%
df["Premiere"] = pd.to_datetime(df["Premiere"], format="mixed")

df
# Out:
#                                            Title   Premiere  Runtime  \
# 0                                Enter the Anime 2019-08-05       58
# 1                                    Dark Forces 2020-08-21       81
# 2                                        The App 2019-12-26       79
# 3                                 The Open House 2018-01-19       94
# 4                                    Kaali Khuhi 2020-10-30       90
# ..                                           ...        ...      ...
# 579        Taylor Swift: Reputation Stadium Tour 2018-12-31      125
# 580  Winter on Fire: Ukraine's Fight for Freedom 2015-10-09       91
# 581                      Springsteen on Broadway 2018-12-16      153
# 582    Emicida: AmarElo - It's All For Yesterday 2020-12-08       89
# 583     David Attenborough: A Life on Our Planet 2020-10-04       83
#
#      IMDB Score                  Language
# 0           2.5          English/Japanese
# 1           2.6                   Spanish
# ...

# %%
df
# Out:
#                                            Title   Premiere  Runtime  \
# 0                                Enter the Anime 2019-08-05       58
# 1                                    Dark Forces 2020-08-21       81
# 2                                        The App 2019-12-26       79
# 3                                 The Open House 2018-01-19       94
# 4                                    Kaali Khuhi 2020-10-30       90
# ..                                           ...        ...      ...
# 579        Taylor Swift: Reputation Stadium Tour 2018-12-31      125
# 580  Winter on Fire: Ukraine's Fight for Freedom 2015-10-09       91
# 581                      Springsteen on Broadway 2018-12-16      153
# 582    Emicida: AmarElo - It's All For Yesterday 2020-12-08       89
# 583     David Attenborough: A Life on Our Planet 2020-10-04       83
#
#      IMDB Score                  Language
# 0           2.5          English/Japanese
# 1           2.6                   Spanish
# ...

# %% [markdown]
# ## 3. Penanganan

# %% [markdown]
# Pengecekan:

# %%
print(df.isnull().sum())
# Out:
# Title         0
# Premiere      0
# Runtime       0
# IMDB Score    0
# Language      0
# dtype: int64

# %% [markdown]
# Penanganan:

# %%
df.dropna(inplace=True)

# %% [markdown]
# *Duplikat*

# %% [markdown]
# Pengecekan:

# %%
print(df.duplicated().sum())
# Out:
# 0

# %% [markdown]
# Penanganan:

# %%
df.drop_duplicates(inplace=True)

# %% [markdown]
# *Outliers*

# %% [markdown]
# Pengecekan:

# %%
Q1 = df['IMDB Score'].quantile(0.25)
Q3 = df['IMDB Score'].quantile(0.75)
IQR = Q3 - Q1

outlier_condition = (df['IMDB Score'] < (Q1 - 1.5 * IQR)) | (df['IMDB Score'] > (Q3 + 1.5 * IQR))
print(df[outlier_condition])
# Out:
#                                         Title   Premiere  Runtime  IMDB Score  \
# 0                             Enter the Anime 2019-08-05       58         2.5
# 1                                 Dark Forces 2020-08-21       81         2.6
# 2                                     The App 2019-12-26       79         2.6
# 3                              The Open House 2018-01-19       94         3.2
# 4                                 Kaali Khuhi 2020-10-30       90         3.4
# 5                                       Drive 2019-11-01      147         3.5
# 6                           Leyla Everlasting 2020-12-04      112         3.7
# 7             The Last Days of American Crime 2020-06-05      149         3.7
# 583  David Attenborough: A Life on Our Planet 2020-10-04       83         9.0
#
#              Language
# 0    English/Japanese
# 1             Spanish
# 2             Italian
# 3             English
# 4               Hindi
# 5               Hindi
# 6             Turkish
# ...

# %% [markdown]
# Penanganan (menghapus outliers):

# %%
df = df[~outlier_condition]

# %% [markdown]
# atau dengan median:

# %%
df.loc[outlier_condition, 'IMDB Score'] = df['IMDB Score'].median()

# %% [markdown]
# *Nilai yang Tidak Konsisten*

# %%
print(df['Language'].unique())
# Out:
# ['English' 'Hindi' 'Korean' 'Indonesian' 'Malay' 'Spanish' 'Dutch'
#  'French' 'Italian' 'English/Spanish' 'Portuguese' 'Filipino' 'German'
#  'Polish' 'Norwegian' 'Marathi' 'Thai' 'Swedish' 'Japanese'
#  'Spanish/Basque' 'Turkish' 'English/Japanese' 'Spanish/Catalan'
#  'English/Swedish' 'English/Taiwanese/Mandarin' 'Thia/English'
#  'English/Mandarin' 'Georgian' 'Bengali' 'Khmer/English/French'
#  'English/Hindi' 'Tamil' 'Spanish/English' 'English/Korean'
#  'English/Arabic' 'English/Russian' 'English/Akan'
#  'English/Ukranian/Russian']

# %%
df['Language'] = df['Language'].replace({'eng': 'English', 'ENGLISH': 'English'})
# Out:
# <ipython-input-90-dc54a64341c1>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Language'] = df['Language'].replace({'eng': 'English', 'ENGLISH': 'English'})

# %%
df = df[df['Runtime'] > 0]

# %% [markdown]
# ## 4. Kontruksi Data

# %%
df["Premiere"] = pd.to_datetime(df["Premiere"], dayfirst=True, errors="coerce")

df["Hari_Rilis"] = df["Premiere"].dt.day_name()

df["Rasio_Runtime_IMDB"] = df["Runtime"] / df["IMDB Score"]

print(df.head())
# Out:
#                    Title   Premiere  Runtime  IMDB Score    Language  \
# 8                Paradox 2018-03-23       73         3.9     English
# 9     Sardar Ka Grandson 2021-05-18      139         4.1       Hindi
# 10  Searching for Sheela 2021-04-22       58         4.1     English
# 11              The Call 2020-11-27      112         4.1      Korean
# 12               Whipped 2020-09-18       97         4.1  Indonesian
#
#    Hari_Rilis  Rasio_Runtime_IMDB
# 8      Friday           18.717949
# 9     Tuesday           33.902439
# 10   Thursday           14.146341
# 11     Friday           27.317073
# 12     Friday           23.658537

# %% [markdown]
# ## 5. Data Reduction

# %%
df = df.drop('Premiere', axis=1)

# %%
df
# Out:
#                                            Title  Runtime  IMDB Score  \
# 8                                        Paradox       73         3.9
# 9                             Sardar Ka Grandson      139         4.1
# 10                          Searching for Sheela       58         4.1
# 11                                      The Call      112         4.1
# 12                                       Whipped       97         4.1
# ..                                           ...      ...         ...
# 578   Ben Platt: Live from Radio City Music Hall       85         8.4
# 579        Taylor Swift: Reputation Stadium Tour      125         8.4
# 580  Winter on Fire: Ukraine's Fight for Freedom       91         8.4
# 581                      Springsteen on Broadway      153         8.5
# 582    Emicida: AmarElo - It's All For Yesterday       89         8.6
#
#                      Language Hari_Rilis  Rasio_Runtime_IMDB
# 8                     English     Friday           18.717949
# ...

# %% [markdown]
# # **CHECKPOINT 3**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Distribusi Rating IMDb Film Netflix

# %%
# Cek kolom dulu
print(df.columns)
# Out:
# Index(['Title', 'Runtime', 'IMDB Score', 'Language', 'Hari_Rilis',
#        'Rasio_Runtime_IMDB'],
#       dtype='object')

# %%
plt.figure(figsize=(8, 5))
sns.histplot(df['IMDB Score'], bins=20, kde=True, color='skyblue')
plt.title('Distribusi IMDB Score Film Netflix')
plt.xlabel('IMDB Score')
plt.ylabel('Jumlah Film')
plt.show()

# %% [markdown]
# insight:
# >Mayoritas film Netflix memiliki IMDB Score di rentang 5.5 hingga 7.5.
# Ini menunjukkan bahwa sebagian besar film di Netflix memiliki kualitas yang cukup hingga baik, berdasarkan penilaian pengguna IMDB.
#
# >Puncak distribusi berada di sekitar skor 6 hingga 7.
# Artinya, film dengan skor menengah (tidak terlalu tinggi atau rendah) paling banyak tersedia di platform Netflix.
#
# >Jumlah film dengan skor rendah (<5) atau sangat tinggi (>8) relatif sedikit.
# Ini menunjukkan bahwa film dengan kualitas sangat buruk atau sangat bagus jumlahnya lebih sedikit dibandingkan film dengan skor menengah.
#
# >Distribusi skor cenderung normal (mendekati simetris) meskipun ada sedikit skew ke kanan (lebih banyak film dengan skor lebih rendah di bawah rata-rata 7).
#
# ✅ Tindakan / Rekomendasi:
# >Meningkatkan jumlah film dengan IMDB Score tinggi (>8):
#
# Netflix bisa berinvestasi pada film-film berkualitas tinggi, baik melalui produksi orisinal (Netflix Original) maupun lisensi film-film terkenal.
# Meningkatkan kerja sama dengan produser, sutradara, dan aktor berkualitas.
# Melakukan kurasi atau evaluasi terhadap film dengan skor rendah (<5):
#
# >Film dengan skor rendah dapat dikaji ulang apakah tetap layak ditayangkan atau perlu disaring.
# Memberikan label peringatan atau kategori khusus bagi film dengan skor rendah agar pengguna bisa memilih dengan sadar.
# Meningkatkan kualitas film dengan skor menengah (5.5 - 7.5):
#
# >Netflix bisa melakukan perbaikan konten berdasarkan ulasan pengguna, misalnya melalui perbaikan alur cerita, kualitas produksi, atau pemilihan genre yang lebih relevan.
# Bisa juga meningkatkan rekomendasi ke pengguna berdasarkan genre dan skor film yang sesuai dengan preferensi mereka.
# Strategi pemasaran berdasarkan skor:
#
# >Film dengan skor tinggi bisa menjadi highlight di halaman utama untuk meningkatkan engagement dan kepuasan pelanggan.
# Film dengan skor menengah dapat dikemas dengan nilai tambah, misalnya mengaitkan dengan trend atau selebriti terkenal.

# %% [markdown]
# ###Distribusi Rating IMDb Film Netflix

# %%
plt.figure(figsize=(8, 5))
sns.histplot(df['Runtime'], bins=20, kde=True, color='darkred')
plt.title('Distribusi Durasi Film Netflix')
plt.xlabel('Durasi (menit)')
plt.ylabel('Jumlah Film')
plt.show()

# %% [markdown]
# Insight:
# >Sebagian besar film Netflix berdurasi antara 85 hingga 110 menit.
# Ini terlihat dari puncak histogram yang berada di sekitar rentang tersebut, menunjukkan durasi favorit atau umum untuk mayoritas film.
#
# >Distribusi durasi film membentuk pola mirip distribusi normal (agak simetris), tetapi sedikit condong ke kanan (right-skewed).
# Ini berarti ada beberapa film dengan durasi sangat panjang (lebih dari 150 menit), tetapi jumlahnya sedikit.
#
# >Terdapat film berdurasi sangat pendek (<30 menit) meskipun jumlahnya relatif kecil, yang bisa jadi merupakan film pendek atau dokumenter singkat.
#
# Durasi paling banyak berkisar 90-100 menit, yang merupakan durasi standar film layar lebar.
#
# ✅ Tindakan / Rekomendasi:
# >Fokus pada produksi dan akuisisi film dengan durasi 90-100 menit.
#
# Karena durasi ini paling banyak ditonton atau diproduksi, Netflix bisa menyesuaikan produksi original movie di rentang durasi ini untuk memenuhi ekspektasi mayoritas penonton.
# Pertimbangkan menambah variasi film pendek (<30 menit) atau film panjang (>150 menit) sesuai kebutuhan niche market.
#
# >Bisa diteliti lebih lanjut apakah film dengan durasi tertentu cenderung mendapatkan rating lebih tinggi, sehingga bisa menjadi pertimbangan dalam produksi konten ke depan.

# %% [markdown]
# ### Trend Tahun Rilis (Hari_Rilis) terhadap Rata-rata IMDB Score

# %%
plt.figure(figsize=(10, 6))
sns.lineplot(data=df.groupby('Hari_Rilis')['IMDB Score'].mean().reset_index(),
             x='Hari_Rilis', y='IMDB Score', marker='o', color='blue')
plt.title('Tren Rata-rata IMDB Score Berdasarkan Tahun Rilis')
plt.xlabel('Tahun Rilis')
plt.ylabel('Rata-rata IMDB Score')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# Insight:
# >Rata-rata IMDB Score film Netflix bervariasi setiap tahun.
# Dari grafik lineplot tersebut terlihat adanya fluktuasi skor rata-rata berdasarkan tahun rilis film.
#
# >Terdapat beberapa tahun dengan penurunan dan kenaikan skor rata-rata.
#
# Ada tahun-tahun tertentu dengan peningkatan kualitas film (ditunjukkan oleh naiknya rata-rata IMDB Score).
# Sebaliknya, ada tahun di mana rata-rata IMDB Score menurun, yang bisa menjadi indikator adanya film-film dengan kualitas kurang baik dirilis di tahun tersebut.
# >Tidak ada tren yang konsisten naik atau turun secara terus menerus.
# Hal ini menunjukkan bahwa kualitas film Netflix belum stabil setiap tahunnya, masih fluktuatif.
#
# ✅ Tindakan / Rekomendasi:
# >Analisis lebih dalam terhadap tahun dengan rata-rata IMDB Score rendah.
#
# Identifikasi film-film apa saja yang dirilis pada tahun tersebut dan mengapa mendapatkan skor rendah (apakah karena genre, kualitas produksi, atau faktor lain).
# Gunakan hasil analisis ini untuk menghindari kesalahan produksi serupa di masa depan.
# Evaluasi dan pertahankan strategi tahun-tahun dengan skor rata-rata tinggi.
#
# >Cari tahu apa yang membuat film-film di tahun dengan skor tinggi menjadi sukses, misalnya: genre yang disukai, kerja sama dengan sutradara/aktor terkenal, atau kualitas produksi.
# Terapkan strategi yang sama atau lebih baik di tahun-tahun mendatang.
# Perbaikan kualitas produksi berdasarkan feedback pengguna.
#
# Gunakan data ini untuk meningkatkan kualitas cerita, akting, dan produksi di tahun-tahun selanjutnya, agar rata-rata IMDB Score bisa meningkat.
# Penyesuaian perencanaan rilis film tahunan.
#
# >Netflix dapat menentukan kuantitas dan jenis film yang akan dirilis tiap tahun dengan mempertimbangkan hasil evaluasi kualitas film di tahun-tahun sebelumnya.
# Meningkatkan promosi dan marketing untuk film berkualitas.
#
# Fokus pada film-film dengan potensi IMDB Score tinggi agar mendapatkan perhatian lebih besar dari pengguna.

# %% [markdown]
# ### Hubungan Durasi dengan IMDB Score

# %%
plt.figure(figsize=(8, 5))
sns.scatterplot(data=df, x='Runtime', y='IMDB Score', color='pink')
plt.title('Hubungan Durasi dengan IMDB Score Film Netflix')
plt.xlabel('Durasi (menit)')
plt.ylabel('IMDB Score')
plt.show()

# %% [markdown]
# Insight:
# >Tidak terdapat korelasi yang jelas antara durasi film dan IMDB Score.
# Dari scatter plot tersebut, sebaran titik-titik (film) terlihat menyebar secara acak, baik untuk film berdurasi pendek maupun panjang. Ini menunjukkan bahwa durasi film tidak secara langsung memengaruhi penilaian IMDB Score.
#
# >Film dengan durasi antara 80 hingga 120 menit mendominasi jumlah film dan memiliki rentang IMDB Score yang bervariasi.
#
# >Banyak film berdurasi standar (90-100 menit) dengan skor berkisar 5 hingga 8, namun ada juga beberapa film dengan durasi tersebut yang mendapatkan skor rendah.
# Film berdurasi sangat pendek (<60 menit) dan sangat panjang (>150 menit) cenderung lebih sedikit jumlahnya.
#
# ✅ Tindakan / Rekomendasi:
# >Fokus pada kualitas isi film, bukan hanya durasi.
#
# Karena durasi tidak berkaitan langsung dengan skor IMDB, maka tim produksi harus lebih fokus ke kualitas cerita, akting, sinematografi, dan penyutradaraan.
# >Optimalkan durasi di kisaran ideal (80-120 menit), tetapi pastikan kontennya kuat.
#
# Meskipun durasi standar ini paling banyak digunakan, tanpa kualitas konten yang baik, skor IMDB tetap bisa rendah. Jadi, jangan hanya terpaku pada durasi standar.
# Eksperimen dengan film pendek atau panjang untuk genre tertentu.
#
# Karena durasi bukan jaminan skor tinggi, cerita yang solid dan karakter yang kuat akan lebih menentukan kualitas film secara keseluruhan.

# %% [markdown]
# ### Bahasa Film Netflix

# %%
plt.figure(figsize=(10, 6))
plt.bar(df['Language'].value_counts().head(10).index,df['Language'].value_counts().head(10).values,color='purple')
plt.title('Jumlah Film per Bahasa (Top 10 Bahasa)', fontsize=14)
plt.xlabel('Bahasa', fontsize=12)
plt.ylabel('Jumlah Film', fontsize=12)
plt.xticks(rotation=45)  # Agar label bahasa tidak tumpang tindih
plt.show()

# %% [markdown]
# Insight:
# >Bahasa Inggris mendominasi jumlah film yang ada di Netflix.
#
# Bahasa Inggris menjadi bahasa utama yang paling banyak digunakan, jauh mengungguli bahasa lain. Ini menunjukkan bahwa konten Netflix mayoritas berasal dari atau ditujukan untuk pasar global yang menggunakan bahasa Inggris.
# >Bahasa non-Inggris juga memiliki representasi yang signifikan, seperti Hindi, Spanish, French, dan Japanese.
#
# Ini menunjukkan adanya variasi dan keberagaman bahasa dalam katalog Netflix, meskipun proporsinya tidak sebesar film berbahasa Inggris.
# Beberapa bahasa lokal atau regional mulai muncul di 10 besar, tetapi masih dengan jumlah film yang jauh lebih sedikit.
#
# Artinya, pasar lokal atau regional mulai dilirik, namun masih banyak peluang untuk pengembangan konten dalam bahasa-bahasa tersebut.
#
# ✅ Tindakan / Rekomendasi:
# > Meningkatkan produksi dan akuisisi film dalam bahasa non-Inggris, terutama yang menempati posisi 5 besar.
#
# Misalnya, Hindi, Spanish, French, Japanese, Korean. Pasar internasional untuk film dengan bahasa tersebut memiliki potensi penonton yang besar.
# Perluasan pasar dengan meningkatkan representasi bahasa lokal/daerah.
#
# >Netflix dapat mengembangkan film dengan bahasa daerah seperti bahasa Indonesia, Thai, Tagalog, dsb untuk memperkuat basis penonton di Asia Tenggara, Asia Selatan, dan negara berkembang lainnya.
# Mendorong subtitel dan dubbing untuk film non-Inggris ke berbagai bahasa populer lainnya.
#
# Hal ini akan memperluas jangkauan penonton global, sehingga meskipun filmnya berbahasa lokal, masih bisa diterima di pasar internasional.
# Melakukan riset pasar untuk mengetahui bahasa yang potensial dikembangkan.
#
# >Data ini bisa digunakan untuk mengevaluasi bahasa apa saja yang belum banyak difasilitasi tapi memiliki potensi besar berdasarkan pertumbuhan pengguna di wilayah tertentu.
# Strategi konten lokal untuk meningkatkan engagement di negara tertentu.
#
# Misalnya, jika jumlah film berbahasa Hindi sudah banyak, Netflix dapat membuat serial/film orisinal dengan bahasa tersebut agar lebih relevan dengan audiens lokal.
